# %% [markdown]
# # Libreria plotly

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import cufflinks as cf
from IPython.display import display,HTML

cf.set_config_file(sharing='public',theme='ggplot',offline=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
# ...

# %%
ticker='BTC-USD'

# %%
df_BTC=yf.download(ticker, start="2020-12-01",end="2022-06-03")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# **Ya cargada la base datos procedemos a ver el DF.**

# %%
df_BTC
# Out:
#                     Open          High           Low         Close  \
# Date
# 2020-12-01  19633.769531  19845.974609  18321.921875  18802.998047
# 2020-12-02  18801.744141  19308.330078  18347.718750  19201.091797
# 2020-12-03  19205.925781  19566.191406  18925.785156  19445.398438
# 2020-12-04  19446.966797  19511.404297  18697.193359  18699.765625
# 2020-12-05  18698.384766  19160.449219  18590.193359  19154.230469
# ...                  ...           ...           ...           ...
# 2022-05-30  29443.365234  31949.630859  29303.572266  31726.390625
# 2022-05-31  31723.865234  32249.863281  31286.154297  31792.310547
# 2022-06-01  31792.554688  31957.285156  29501.587891  29799.080078
# 2022-06-02  29794.890625  30604.734375  29652.705078  30467.488281
# 2022-06-03  30467.806641  30633.035156  29375.689453  29704.390625
#
#                Adj Close       Volume
# Date
# 2020-12-01  18802.998047  49633658712
# 2020-12-02  19201.091797  37387697139
# ...

# %% [markdown]
# **Vamos hacer una lista con las 5 criptomonedas elegidas**

# %%
criptos_mone=['BTC-USD','ETH-USD','DOGE-USD','BNB-USD','ADA-USD']

# %% [markdown]
# ***Creamos un diccionario vacio***

# %%
criptos_info = dict()

# %% [markdown]
# ***Vamos a crear un for para ingresar todos los datos de en el diccionario***

# %%
for ticker in criptos_mone:
  criptos_info[ticker]=df_market=yf.download(ticker, start="2020-12-01",end="2022-06-03")
  print(f'{ticker} - ok')
# Out:
# [*********************100%***********************]  1 of 1 completed
# BTC-USD - ok
# [*********************100%***********************]  1 of 1 completed
# ETH-USD - ok
# [*********************100%***********************]  1 of 1 completed
# DOGE-USD - ok
# [*********************100%***********************]  1 of 1 completed
# BNB-USD - ok
# [*********************100%***********************]  1 of 1 completed
# ADA-USD - ok

# %% [markdown]
# ***Vemos si se cargo el diccionario de forma correcta***

# %%
criptos_info
# Out:
# {'BTC-USD':                     Open          High           Low         Close  \
#  Date
#  2020-12-01  19633.769531  19845.974609  18321.921875  18802.998047
#  2020-12-02  18801.744141  19308.330078  18347.718750  19201.091797
#  2020-12-03  19205.925781  19566.191406  18925.785156  19445.398438
#  2020-12-04  19446.966797  19511.404297  18697.193359  18699.765625
#  2020-12-05  18698.384766  19160.449219  18590.193359  19154.230469
#  ...                  ...           ...           ...           ...
#  2022-05-30  29443.365234  31949.630859  29303.572266  31726.390625
#  2022-05-31  31723.865234  32249.863281  31286.154297  31792.310547
#  2022-06-01  31792.554688  31957.285156  29501.587891  29799.080078
#  2022-06-02  29794.890625  30604.734375  29652.705078  30467.488281
#  2022-06-03  30467.806641  30633.035156  29375.689453  29704.390625
#
#                 Adj Close       Volume
#  Date
#  2020-12-01  18802.998047  49633658712
#  2020-12-02  19201.091797  37387697139
# ...

# %% [markdown]
# ***Sacaremos los rendimientos para el BITCOIN, agregamos una nueva columna***

# %%
df_BTC['Rendimientos']=(df_BTC['Close']-df_BTC['Open'])/df_BTC['Open']
df_BTC
# Out:
#                     Open          High           Low         Close  \
# Date
# 2020-12-01  19633.769531  19845.974609  18321.921875  18802.998047
# 2020-12-02  18801.744141  19308.330078  18347.718750  19201.091797
# 2020-12-03  19205.925781  19566.191406  18925.785156  19445.398438
# 2020-12-04  19446.966797  19511.404297  18697.193359  18699.765625
# 2020-12-05  18698.384766  19160.449219  18590.193359  19154.230469
# ...                  ...           ...           ...           ...
# 2022-05-30  29443.365234  31949.630859  29303.572266  31726.390625
# 2022-05-31  31723.865234  32249.863281  31286.154297  31792.310547
# 2022-06-01  31792.554688  31957.285156  29501.587891  29799.080078
# 2022-06-02  29794.890625  30604.734375  29652.705078  30467.488281
# 2022-06-03  30467.806641  30633.035156  29375.689453  29704.390625
#
#                Adj Close       Volume  Rendimientos
# Date
# 2020-12-01  18802.998047  49633658712     -0.042313
# ...

# %% [markdown]
# ***Graficamos de los rendimientos solo de Bitcoin***

# %%
df_BTC['Rendimientos'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ***Cramos un for para agregar al diccionario los rendmientos de las cinco criptomonedas***

# %%
for ticker in criptos_mone:
  criptos_info[ticker]['Rendimientos']=(criptos_info[ticker]['Close']-criptos_info[ticker]['Open'])/criptos_info[ticker]['Open']
  print(f'{ticker} - ok')
# Out:
# BTC-USD - ok
# ETH-USD - ok
# DOGE-USD - ok
# BNB-USD - ok
# ADA-USD - ok

# %% [markdown]
# ***Imprimimos el diccionario***

# %%
criptos_info
# Out:
# {'BTC-USD':                     Open          High           Low         Close  \
#  Date
#  2020-12-01  19633.769531  19845.974609  18321.921875  18802.998047
#  2020-12-02  18801.744141  19308.330078  18347.718750  19201.091797
#  2020-12-03  19205.925781  19566.191406  18925.785156  19445.398438
#  2020-12-04  19446.966797  19511.404297  18697.193359  18699.765625
#  2020-12-05  18698.384766  19160.449219  18590.193359  19154.230469
#  ...                  ...           ...           ...           ...
#  2022-05-30  29443.365234  31949.630859  29303.572266  31726.390625
#  2022-05-31  31723.865234  32249.863281  31286.154297  31792.310547
#  2022-06-01  31792.554688  31957.285156  29501.587891  29799.080078
#  2022-06-02  29794.890625  30604.734375  29652.705078  30467.488281
#  2022-06-03  30467.806641  30633.035156  29375.689453  29704.390625
#
#                 Adj Close       Volume  Rendimientos
#  Date
#  2020-12-01  18802.998047  49633658712     -0.042313
# ...

# %% [markdown]
# ***Probaremos la visualización de los DF de cada cripto, en este caso usaremos de ejemplo la DOGECOIN***

# %%
criptos_info['DOGE-USD']
# Out:
#                 Open      High       Low     Close  Adj Close     Volume  \
# Date
# 2020-12-01  0.003551  0.003572  0.003269  0.003335   0.003335   80163603
# 2020-12-02  0.003335  0.003436  0.003293  0.003374   0.003374   58705661
# 2020-12-03  0.003375  0.003500  0.003352  0.003428   0.003428   47907032
# 2020-12-04  0.003429  0.003447  0.003285  0.003298   0.003298   45062222
# 2020-12-05  0.003297  0.003414  0.003268  0.003397   0.003397   43386583
# ...              ...       ...       ...       ...        ...        ...
# 2022-05-30  0.082684  0.088275  0.082269  0.087871   0.087871  690696756
# 2022-05-31  0.087865  0.088230  0.083612  0.085865   0.085865  672444588
# 2022-06-01  0.085855  0.088647  0.079807  0.081056   0.081056  830748610
# 2022-06-02  0.081052  0.083007  0.080417  0.082772   0.082772  434510607
# 2022-06-03  0.082777  0.082857  0.079756  0.080442   0.080442  403339248
#
#             Rendimientos
# Date
# 2020-12-01     -0.060828
# 2020-12-02      0.011694
# ...

# %% [markdown]
# ***Hacemos la gráfica de los rendimientos las cinco criptos***

# %%
for ticker in criptos_mone:
  plt.plot(criptos_info[ticker].index,criptos_info[ticker]['Rendimientos'])
plt.Figure()

# %% [markdown]
# ***Ahora hacemos la grafica tablas dinamicas para Bitcoin y despues con todas***

# %%
df_BTC[["Rendimientos"]].iplot(kind='line')
# Out:
# <div>                            <div id="5fff1c01-60d5-41d0-be02-ceaf3f27b888" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df_BTC.iplot(kind='bar')
# Out:
# <div>                            <div id="e79bd028-b647-44b4-a901-4322d234da3f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# ### Ahora instalaremos la libreria QuantLib

# %%
pip install QuantLib
# Out:
# ...
# WARNING: You are using pip version 20.2.3; however, version 22.1.2 is available.
# You should consider upgrading via the 'c:\users\peluche\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.

# %%
import QuantLib as ql

# %% [markdown]
# # Valorización de Opciones Europeas.
#
# ####  Opción Call

# %%
import numpy as np
import scipy.stats as st

def BS_Vanilla_Call(S, K, T, r, sigma):
    #S: precio spot
    #K: precio strike
    #T: tiempo de vencimiento
    #r: tasa de interes
    #sigma: volatilidad del activo
    
    d1 = (np.log(S / K) + (r + 0.5 * sigma ** 2) * T) / (sigma * np.sqrt(T))
    d2 = d1 - (sigma * np.sqrt(T))
    C = (S * st.norm.cdf(d1, 0.0, 1.0) - K * np.exp(-r * T) * st.norm.cdf(d2, 0.0, 1.0))
    return C

#Probando la función de Python
a = BS_Vanilla_Call(90, 100, 1, 0.05, 0.25)

print("Precio Call Option: {:0.6f}".format(a))
# Out:
# Precio Call Option: 6.869814

# %% [markdown]
# ### Opción Put

# %%
def BS_Vanilla_Put(S, K, T, r, sigma):
    #S: precio spot
    #K: precio strike
    #T: tiempo de vencimiento
    #r: tasa de interes
    #sigma: volatilidad del activo
    
    d1 = (np.log(S / K) + (r + 0.5 * sigma ** 2) * T) / (sigma * np.sqrt(T))
    d2 = d1 - (sigma * np.sqrt(T))
    P = K * np.exp(-r * T) * st.norm.cdf(-d2, 0.0, 1.0) - S * st.norm.cdf(-d1, 0.0, 1.0) 
    return P

#Probando la función de Python
a = BS_Vanilla_Put(90, 100, 1, 0.05, 0.25)

print("Precio Put Option: {:0.6f}".format(a))
# Out:
# Precio Put Option: 11.992757

# %% [markdown]
# ## Valorizacion de Opciones con QuantLib.
# Bueno ahora les presentaré QuantLib. QuantLib es una libreria de C, diseñada para la valorizacion de instrumentos financieros (opciones, forwardas, swaps y bonos). Como la libreria esta diseñada en C la nomenclatura es algo complicada, pero las ventajas de esta libreria es que tiene desarrollada la valorizacion de muchos instrumentos financieros bajo diferentes metodos (arboles binomiales, forma analitica, simulacion de montecarlo entre otras), tambien las griegas de opciones y duracion y convexidad para bonos. Entre las desventajas estan que la documentación es algo confusa para los que no saben C o no estan familiarizados con algun lenguaje de programación.
#
# Ahora sin mas preambulos vamos a crear una opción call con QuantLibPython.

# %%
T = ql.Date(15, 2, 2019)
S = ql.SimpleQuote(90)
K = 100
sigma = 0.25 # the historical vols for a year
div_rate =  0.00
option_type = ql.Option.Call

r = 0.05
day_count = ql.Actual365Fixed()
calendar = ql.UnitedStates()

t_0 = T - 365
ql.Settings.instance().evaluationDate = t_0

# Construimos la opción
payoff = ql.PlainVanillaPayoff(option_type, K)
exercise = ql.EuropeanExercise(T)
call_option = ql.VanillaOption(payoff, exercise)

# Construimos el proceso para valorizar la opción
# En este caso usaremos un proceso estocastico de Black Scholes Merton
spot_handle = ql.QuoteHandle(S)
flat_ts = ql.YieldTermStructureHandle(ql.FlatForward(0, calendar, r, day_count))
div_yield = ql.YieldTermStructureHandle(ql.FlatForward(0, calendar, div_rate, day_count))
flat_vol_ts = ql.BlackVolTermStructureHandle(ql.BlackConstantVol(0, calendar, sigma, day_count))
bsm_process = ql.BlackScholesMertonProcess(spot_handle, 
                                           div_yield, 
                                           flat_ts, 
                                           flat_vol_ts)

# Añadimos el proceso a la opcion
call_option.setPricingEngine(ql.AnalyticEuropeanEngine(bsm_process))

bs_price1 = call_option.NPV()

bs_price = BS_Vanilla_Call(90, 100, 1, 0.05, 0.25)

print("Precio Call Option Python Puro : {:0.6f}".format(bs_price))
print("Precio Call Option con QuantLib: {:0.6f}".format(bs_price1))
# Out:
# Precio Call Option Python Puro : 6.869814
# Precio Call Option con QuantLib: 6.869814

# %% [markdown]
# # Valorización de Opciones Americanas.
# ## Opción Call
# Las opciones americanas son opciones que a diferencia de las europeas, pueden ser ejercidas en cualquier momento del tiempo. No tienen una formula explicita para el calculo de su precio, sin embargo se puede calcular sus precios con varios metodos como los metodos analiticos, arboles binomiales, diferencias finitas y simulacion de montecarlo:
# Ahora vamos a probar los diferentes metodos para valorizar una opción americana yeeee =D.

# %%
steps = 100
S.setValue(90)
exercise_am = ql.AmericanExercise(t_0, T)
call_option_am = ql.VanillaOption(payoff, exercise_am)

# %% [markdown]
# # Usando los arboles binomiales.

# %%
binomials = ['jr','crr','eqp','trigeorgis','tian','lr',]
for i in binomials:
    binomial_engine = ql.BinomialVanillaEngine(bsm_process, i, steps)
    call_option_am.setPricingEngine(binomial_engine)
    print("Binomial ("+ str(i) +") : {:0.6f}".format(call_option_am.NPV()))
# Out:
# Binomial (jr) : 6.880626
# Binomial (crr) : 6.860421
# Binomial (eqp) : 6.836585
# Binomial (trigeorgis) : 6.860736
# Binomial (tian) : 6.869117
# Binomial (lr) : 6.765350

# %% [markdown]
# # Usando la simulacion de MonteCarlo.

# %%
montecarlo_engine = ql.MCAmericanEngine(bsm_process, 'PseudoRandom', 
                                        timeSteps = steps,
                                        requiredSamples = 1000,
                                        requiredTolerance = 0.01,
                                        seed = 1,
                                        seedCalibration = 1)

call_option_am.setPricingEngine(montecarlo_engine)
print("MonteCarlo: {:0.6f}".format(call_option_am.NPV()))
# Out:
# MonteCarlo: 6.639045
